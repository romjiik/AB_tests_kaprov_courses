# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff

# %%
df = pd.read_csv('stratification_task_data_public.csv')

# %%
df
# Out:
#          x1  x2    x3  x4  x5    x6    x7  x8  x9  x10     y
# 0     0.869  30  33.8   0   1   0.2  1992   1   1    1  1903
# 1     0.759  27  21.7   2   0   3.5  1995   1   1    2  1313
# 2     0.456  29  37.6   2   0   3.1  1993   0   0    0  1484
# 3     0.060  35  27.5   2   0   4.7  1988   0   0    1  1188
# 4     0.939  19  30.7   0   0   3.6  2003   1   1    2   842
# ...     ...  ..   ...  ..  ..   ...   ...  ..  ..  ...   ...
# 9995  0.844  31  31.7   0   0   1.8  1992   1   0    3  1798
# 9996  0.342  27  32.5   1   0   1.8  1996   1   0    0  1457
# 9997  0.679  28  29.7   1   0   0.8  1994   1   0    2  1477
# 9998  0.724  22  38.4   0   0   4.6  2000   1   0    2  1484
# 9999  0.466  24  27.9   2   0  16.0  1998   0   1    2  1167
#
# [10000 rows x 11 columns]

# %%
len(df)
# Out:
# 10000

# %%
corr = df.corr()
corr.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_3ff0b_row0_col0, #T_3ff0b_row1_col1, #T_3ff0b_row2_col2, #T_3ff0b_row3_col3, #T_3ff0b_row4_col4, #T_3ff0b_row5_col5, #T_3ff0b_row6_col6, #T_3ff0b_row7_col7, #T_3ff0b_row8_col8, #T_3ff0b_row9_col9, #T_3ff0b_row10_col10 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_3ff0b_row0_col1, #T_3ff0b_row2_col1, #T_3ff0b_row4_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_3ff0b_row0_col2, #T_3ff0b_row0_col4, #T_3ff0b_row0_col5, #T_3ff0b_row1_col6, #T_3ff0b_row1_col7, #T_3ff0b_row1_col9, #T_3ff0b_row1_col10, #T_3ff0b_row2_col0, #T_3ff0b_row2_col7, #T_3ff0b_row4_col0, #T_3ff0b_row5_col0, #T_3ff0b_row5_col3, #T_3ff0b_row6_col1, #T_3ff0b_row6_col3, #T_3ff0b_row8_col4, #T_3ff0b_row9_col3, #T_3ff0b_row10_col2, #T_3ff0b_row10_col8 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_3ff0b_row0_col3, #T_3ff0b_row1_col3, #T_3ff0b_row1_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_3ff0b_row0_col6, #T_3ff0b_row2_col6, #T_3ff0b_row4_col6, #T_3ff0b_row7_col6, #T_3ff0b_row8_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_3ff0b_row0_col7, #T_3ff0b_row2_col10, #T_3ff0b_row3_col5, #T_3ff0b_row4_col7, #T_3ff0b_row5_col7, #T_3ff0b_row5_col9, #T_3ff0b_row6_col5, #T_3ff0b_row8_col2, #T_3ff0b_row9_col0, #T_3ff0b_row9_col5, #T_3ff0b_row10_col3, #T_3ff0b_row10_col5 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_3ff0b_row0_col8, #T_3ff0b_row0_col10, #T_3ff0b_row3_col8, #T_3ff0b_row6_col9, #T_3ff0b_row7_col8, #T_3ff0b_row9_col8 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_3ff0b_row0_col9, #T_3ff0b_row1_col5, #T_3ff0b_row2_col3, #T_3ff0b_row2_col5, #T_3ff0b_row3_col0, #T_3ff0b_row3_col9, #T_3ff0b_row4_col3, #T_3ff0b_row5_col2, #T_3ff0b_row5_col8, #T_3ff0b_row6_col8, #T_3ff0b_row7_col3, #T_3ff0b_row7_col4, #T_3ff0b_row8_col3, #T_3ff0b_row8_col7, #T_3ff0b_row9_col7, #T_3ff0b_row10_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_3ff0b_row1_col0, #T_3ff0b_row1_col2, #T_3ff0b_row4_col8, #T_3ff0b_row6_col7, #T_3ff0b_row7_col2, #T_3ff0b_row8_col5, #T_3ff0b_row8_col10 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_3ff0b_row1_col8, #T_3ff0b_row3_col4, #T_3ff0b_row4_col5, #T_3ff0b_row5_col10, #T_3ff0b_row7_col0, #T_3ff0b_row7_col5, #T_3ff0b_row8_col0, #T_3ff0b_row9_col2, #T_3ff0b_row9_col4 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_3ff0b_row2_col4, #T_3ff0b_row2_col8, #T_3ff0b_row3_col7, #T_3ff0b_row4_col2, #T_3ff0b_row5_col4, #T_3ff0b_row6_col0, #T_3ff0b_row6_col2, #T_3ff0b_row6_col4 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_3ff0b_row2_col9, #T_3ff0b_row3_col2, #T_3ff0b_row4_col9, #T_3ff0b_row7_col9, #T_3ff0b_row8_col9 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_3ff0b_row3_col1, #T_3ff0b_row3_col6, #T_3ff0b_row5_col1, #T_3ff0b_row5_col6, #T_3ff0b_row7_col1, #T_3ff0b_row8_col6 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_3ff0b_row3_col10 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_3ff0b_row4_col10, #T_3ff0b_row6_col10 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_3ff0b_row7_col10 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_3ff0b_row9_col1 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_3ff0b_row9_col6 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_3ff0b_row9_col10 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_3ff0b_row10_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_3ff0b_row10_col4 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_3ff0b_row10_col6 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_3ff0b_row10_col7 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_3ff0b_row10_col9 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3ff0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ff0b_level0_col0" class="col_heading level0 col0" >x1</th>
#       <th id="T_3ff0b_level0_col1" class="col_heading level0 col1" >x2</th>
#       <th id="T_3ff0b_level0_col2" class="col_heading level0 col2" >x3</th>
#       <th id="T_3ff0b_level0_col3" class="col_heading level0 col3" >x4</th>
#       <th id="T_3ff0b_level0_col4" class="col_heading level0 col4" >x5</th>
#       <th id="T_3ff0b_level0_col5" class="col_heading level0 col5" >x6</th>
#       <th id="T_3ff0b_level0_col6" class="col_heading level0 col6" >x7</th>
#       <th id="T_3ff0b_level0_col7" class="col_heading level0 col7" >x8</th>
#       <th id="T_3ff0b_level0_col8" class="col_heading level0 col8" >x9</th>
#       <th id="T_3ff0b_level0_col9" class="col_heading level0 col9" >x10</th>
#       <th id="T_3ff0b_level0_col10" class="col_heading level0 col10" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ff0b_level0_row0" class="row_heading level0 row0" >x1</th>
#       <td id="T_3ff0b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3ff0b_row0_col1" class="data row0 col1" >-0.005929</td>
#       <td id="T_3ff0b_row0_col2" class="data row0 col2" >-0.012855</td>
#       <td id="T_3ff0b_row0_col3" class="data row0 col3" >0.001497</td>
#       <td id="T_3ff0b_row0_col4" class="data row0 col4" >-0.014040</td>
#       <td id="T_3ff0b_row0_col5" class="data row0 col5" >-0.015988</td>
#       <td id="T_3ff0b_row0_col6" class="data row0 col6" >0.005006</td>
#       <td id="T_3ff0b_row0_col7" class="data row0 col7" >0.008268</td>
#       <td id="T_3ff0b_row0_col8" class="data row0 col8" >0.009632</td>
#       <td id="T_3ff0b_row0_col9" class="data row0 col9" >-0.000988</td>
#       <td id="T_3ff0b_row0_col10" class="data row0 col10" >0.001949</td>
#     </tr>
#     <tr>
#       <th id="T_3ff0b_level0_row1" class="row_heading level0 row1" >x2</th>
#       <td id="T_3ff0b_row1_col0" class="data row1 col0" >-0.005929</td>
#       <td id="T_3ff0b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3ff0b_row1_col2" class="data row1 col2" >-0.006367</td>
#       <td id="T_3ff0b_row1_col3" class="data row1 col3" >0.002223</td>
#       <td id="T_3ff0b_row1_col4" class="data row1 col4" >-0.006278</td>
#       <td id="T_3ff0b_row1_col5" class="data row1 col5" >0.001817</td>
#       <td id="T_3ff0b_row1_col6" class="data row1 col6" >-0.994133</td>
#       <td id="T_3ff0b_row1_col7" class="data row1 col7" >-0.003189</td>
#       <td id="T_3ff0b_row1_col8" class="data row1 col8" >0.004515</td>
#       <td id="T_3ff0b_row1_col9" class="data row1 col9" >-0.017679</td>
#       <td id="T_3ff0b_row1_col10" class="data row1 col10" >-0.031074</td>
#     </tr>
#     <tr>
#       <th id="T_3ff0b_level0_row2" class="row_heading level0 row2" >x3</th>
#       <td id="T_3ff0b_row2_col0" class="data row2 col0" >-0.012855</td>
#       <td id="T_3ff0b_row2_col1" class="data row2 col1" >-0.006367</td>
#       <td id="T_3ff0b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3ff0b_row2_col3" class="data row2 col3" >0.014967</td>
#       <td id="T_3ff0b_row2_col4" class="data row2 col4" >0.006089</td>
#       <td id="T_3ff0b_row2_col5" class="data row2 col5" >0.000260</td>
#       <td id="T_3ff0b_row2_col6" class="data row2 col6" >0.005265</td>
#       <td id="T_3ff0b_row2_col7" class="data row2 col7" >-0.006652</td>
#       <td id="T_3ff0b_row2_col8" class="data row2 col8" >-0.000694</td>
#       <td id="T_3ff0b_row2_col9" class="data row2 col9" >0.010359</td>
#       <td id="T_3ff0b_row2_col10" class="data row2 col10" >-0.016386</td>
#     </tr>
#     <tr>
#       <th id="T_3ff0b_level0_row3" class="row_heading level0 row3" >x4</th>
#       <td id="T_3ff0b_row3_col0" class="data row3 col0" >0.001497</td>
#       <td id="T_3ff0b_row3_col1" class="data row3 col1" >0.002223</td>
#       <td id="T_3ff0b_row3_col2" class="data row3 col2" >0.014967</td>
#       <td id="T_3ff0b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3ff0b_row3_col4" class="data row3 col4" >0.012947</td>
#       <td id="T_3ff0b_row3_col5" class="data row3 col5" >-0.000159</td>
#       <td id="T_3ff0b_row3_col6" class="data row3 col6" >-0.003701</td>
#       <td id="T_3ff0b_row3_col7" class="data row3 col7" >0.013017</td>
#       <td id="T_3ff0b_row3_col8" class="data row3 col8" >0.012899<

# %%
df.groupby(['x2'], as_index=False)['y'].mean()
# Out:
#     x2            y
# 0   12   572.500000
# 1   15   677.500000
# 2   16   746.750000
# 3   17   897.777778
# 4   18   950.291667
# 5   19  1107.700000
# 6   20  1058.162162
# 7   21  1094.780303
# 8   22  1146.612245
# 9   23  1209.298932
# 10  24  1266.679389
# 11  25  1309.786585
# 12  26  1332.519008
# 13  27  1414.238558
# 14  28  1455.895808
# 15  29  1501.949173
# 16  30  1553.356148
# 17  31  1488.491745
# 18  32  1437.884319
# 19  33  1404.683109
# 20  34  1342.956446
# 21  35  1283.213303
# 22  36  1244.922414
# 23  37  1230.230769
# 24  38  1148.271028
# 25  39  1098.275000
# 26  40  1074.666667
# 27  41   989.000000
# 28  42   995.439024
# 29  43   771.900000
# 30  44   976.000000
# 31  45   740.500000
# 32  46   851.666667
# 33  47   518.000000
# 34  48   966.000000
# 35  49   684.000000

# %%
fig = px.box(df, x='x2', y='y')
fig.show()

# %%
# путем пристального взгляда делим на страты
df['strat'] = 1
df.loc[(df['x2'] < 23) | (df['x2'] > 37), 'strat'] = 2
df.loc[(df['x2'] > 28) & (df['x2'] < 32), 'strat'] = 3
df.loc[((df['x2'] >= 25) & (df['x2'] <= 28)) | ((df['x2'] >= 32) & (df['x2'] <= 34)), 'strat'] = 4
print(df.groupby('strat')['y'].mean())
print(df['strat'].value_counts(normalize=True))
# Out:
# strat
# 1    1251.406701
# 2    1083.233879
# 3    1514.821205
# 4    1393.922122
# Name: y, dtype: float64
# strat
# 4    0.4674
# 3    0.2556
# 1    0.1731
# 2    0.1039
# Name: proportion, dtype: float64

# %% [markdown]
# # Эталонное решение

# %% [markdown]
# ## Без ML

# %%
def get_strats(df: pd.DataFrame):
    """Возвращает страты объектов.
    
    :return (list | np.array | pd.Series): список страт объектов размера len(df).
    """
    return [
        str(int(26 <= x <= 34)) + str(int(28 <= x <= 32)) + str(int(y > 1)) + str(int(a == b))
        for x, y, a, b in df[['x2', 'x10', 'x5', 'x9']].values
    ]

# %% [markdown]
# ## С ML

# %%
def calculate_strat_var(df):
    """Вычисляет стратифицированную дисперсию популяции."""
    strat_vars = df.groupby('strat')['y'].var()
    weights = df['strat'].value_counts(normalize=True)
    stratified_var = (strat_vars * weights).sum()
    return stratified_var

# %%
from lightgbm import LGBMRegressor

df_train = df.iloc[:len(df) // 2].copy()
df_test = df.iloc[len(df) // 2:].copy()

model = LGBMRegressor(num_leaves=3)
feature_names = [f'x{i}' for i in range(1, 11)]
model.fit(df_train[feature_names].values, df_train['y'].values)
predict_test = model.predict(df_test[feature_names].values)

n_strat = 10
quantiles = np.quantile(predict_test, np.linspace(0, 1 - 1 / n_strat, n_strat))
df_test['strat'] = [np.sum(predict >= quantiles) for predict in predict_test]
print(int(calculate_strat_var(df_test)))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000323 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 769
# [LightGBM] [Info] Number of data points in the train set: 5000, number of used features: 10
# [LightGBM] [Info] Start training from score 1370.817800
# 42289

# %%
metrics_strat_a_group = np.zeros((10, 2,))
metrics_strat_a_group[:, 0] = np.arange(10)
metrics_strat_a_group[:, 1] = (np.arange(10) < 4).astype(float)
metrics_strat_b_group = np.zeros((10, 2,))
metrics_strat_b_group[:, 0] = np.arange(1, 11)
metrics_strat_b_group[:, 1] = (np.arange(10) < 5).astype(float)

# %%
metrics = np.vstack([metrics_strat_a_group, metrics_strat_b_group])

# %%
metrics_strat_a_group
# Out:
# array([[0., 1.],
#        [1., 1.],
#        [2., 1.],
#        [3., 1.],
#        [4., 0.],
#        [5., 0.],
#        [6., 0.],
#        [7., 0.],
#        [8., 0.],
#        [9., 0.]])

# %%
metrics_strat_b_group[:, 0].mean()
# Out:
# 5.5

# %%
from scipy import stats

metrics_strat_a_group = np.zeros((10, 2,))
metrics_strat_a_group[:, 0] = np.arange(10)
metrics_strat_a_group[:, 1] = (np.arange(10) < 4).astype(float)
metrics_strat_b_group = np.zeros((10, 2,))
metrics_strat_b_group[:, 0] = np.arange(1, 11)
metrics_strat_b_group[:, 1] = (np.arange(10) < 5).astype(float)

df_a = pd.DataFrame(metrics_strat_a_group, columns=['metric', 'strat'])
df_b = pd.DataFrame(metrics_strat_b_group, columns=['metric', 'strat'])
df = pd.concat([df_a, df_b])

strats_share = df['strat'].value_counts(normalize=True)

mean_a = (df_a.groupby('strat')['metric'].mean() * strats_share).sum()
mean_b = (df_b.groupby('strat')['metric'].mean() * strats_share).sum()

var_a = (df_a.groupby('strat')['metric'].var() * strats_share).sum()
var_b = (df_b.groupby('strat')['metric'].var() * strats_share).sum()

delta = mean_b - mean_a
std = (var_a / len(df_a) + var_b / len(df_b)) ** 0.5

t = delta / std
p_val = (1 - stats.norm.cdf(np.abs(t))) * 2
print(p_val)
# Out:
# 0.037056218564119

# %%
df['strat'].value_counts(normalize=True)
# Out:
# strat
# 0.0    0.55
# 1.0    0.45
# Name: proportion, dtype: float64
